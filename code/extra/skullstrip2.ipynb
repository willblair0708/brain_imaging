# %%
import os
import subprocess
import os
import shlex
import subprocess
from nilearn import plotting
import matplotlib
import matplotlib.pyplot as plt
import nibabel as nib

root_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir))

def main():
    # Change the working directory to the "data" folder
    os.chdir('../data/input')

    # Get the list of patient folders
    patient_folders = [folder for folder in os.listdir() if os.path.isdir(folder) and folder.startswith('E')]

    # Create the "output" subfolder in each patient folder if it doesn't exist
    for patient_folder in patient_folders:
        output_path = os.path.join(patient_folder)
        if not os.path.exists(output_path):
            os.makedirs(output_path)

    # Define the input image filenames
    input_image_filenames = [
        'T2w_1mm_noalign.nii.gz',
        'T1w_1mm.nii.gz',
        'ADC_deformed.nii.gz',
        'FA_deformed.nii.gz'
    ]
    
    # Run BET on each patient folder for each input image and save the output with the same name
    for patient_folder in patient_folders:
        for input_image_filename in input_image_filenames:
            input_image_path = os.path.join(patient_folder, input_image_filename)
            output_image_path = os.path.join(patient_folder, input_image_filename)

            command = f'bet "{input_image_path}" "{output_image_path}" -R -f 0.5 -g 0'
            subprocess.run(command, shell=True)

if __name__ == "__main__":
    main()

def display_image(image_file, title):
    """
    Display NIfTI image using nilearn.
    
    Args:
        image_file (str): Path to the NIfTI file.
        title (str): Title of the plot.
    """
    plotting.plot_anat(image_file, title=title, display_mode='ortho')
    plotting.show()

display_image(os.path.join(root_dir, 'data','input','E03', "T2w_1mm_noalign.nii.gz"), "T2w Original")
display_image(os.path.join(root_dir, 'data','input','E03', 'output', "T2w_1mm_noalign.nii.gz"), "T2w Skull Stripped")
display_image(os.path.join(root_dir, 'data','input','E03', "T1w_1mm.nii.gz"), "T1w Original")
display_image(os.path.join(root_dir, 'data','input','E03', 'output', "T1w_1mm.nii.gz"), "T1w Skull Stripped")
display_image(os.path.join(root_dir, 'data','input','E03', "ADC_deformed.nii.gz"), "ADC Original")
display_image(os.path.join(root_dir, 'data','input','E03', 'output', "ADC_deformed.nii.gz"), "ADC Skull Stripped")
display_image(os.path.join(root_dir, 'data','input','E03', "FA_deformed.nii.gz"), "FA Original")
display_image(os.path.join(root_dir, 'data','input','E03', 'output', "FA_deformed.nii.gz"), "FA Skull Stripped")

#change back to code directory
os.chdir('..')
os.chdir('..')
os.chdir('code')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 58
#      55     plotting.show()
#      57 display_image(os.path.join(root_dir, 'data','input','E03', "T2w_1mm_noalign.nii.gz"), "T2w Original")
# ---> 58 display_image(os.path.join(root_dir, 'data','input','E03', 'output', "T2w_1mm_noalign.nii.gz"), "T2w Skull Stripped")
#      59 display_image(os.path.join(root_dir, 'data','input','E03', "T1w_1mm.nii.gz"), "T1w Original")
#      60 display_image(os.path.join(root_dir, 'data','input','E03', 'output', "T1w_1mm.nii.gz"), "T1w Skull Stripped")
#
# Cell In[1], line 54, in display_image(image_file, title)
#      46 def display_image(image_file, title):
#      47     """
#      48     Display NIfTI image using nilearn.
#      49
#    (...)
#      52         title (str): Title of the plot.
#      53     """
# ---> 54     plotting.plot_anat(image_file, title=title, display_mode='ortho')
#      55     plotting.show()
#
# File ~/williamblair/miniconda/envs/tensorflow/lib/python3.8/site-packages/nilearn/plotting/img_plotting.py:463, in plot_anat(anat_img, cut_coords, output_file, display_mode, figure, axes, title, annotate, threshold, draw_cross, black_bg, dim, cmap, colorbar, cbar_tick_format, vmin, vmax, **kwargs)
#     413 @fill_doc
#     414 def plot_anat(anat_img=MNI152TEMPLATE, cut_coords=None,
#     415               output_file=None, display_mode='ortho', figure=None,
#    (...)
#     418               colorbar=False, cbar_tick_format="%.2g", vmin=None,
#     419               vmax=None, **kwargs):
#     420     """Plot cuts of an anatomical image (by default 3 cuts:
#     421     Frontal, Axial, and Lateral)
#     422
#    (...)
#     461
#     462     """
# --> 463     anat_img, black_bg, anat_vmin, anat_vmax = _load_anat(
#     464         anat_img,
#     465         dim=dim, black_bg=black_bg)
#     467     if vmin is None:
#     468         vmin = anat_vmin
#
# File ~/williamblair/miniconda/envs/tensorflow/lib/python3.8/site-packages/nilearn/plotting/img_plotting.py:374, in _load_anat(anat_img, dim, black_bg)
#     372         black_bg = False
#     373 else:
# --> 374     anat_img = _utils.check_niimg_3d(anat_img)
#     375     # Clean anat_img for non-finite values to avoid computing unnecessary
#     376     # border data values.
#     377     data = _safe_get_data(anat_img, ensure_finite=True)
#
# File ~/williamblair/miniconda/envs/tensorflow/lib/python3.8/site-packages/nilearn/_utils/niimg_conversions.py:371, in check_niimg_3d(niimg, dtype)
#     337 def check_niimg_3d(niimg, dtype=None):
#     338     """Check that niimg is a proper 3D niimg-like object and load it.
#     339
#     340     Parameters
#    (...)
#     369
#     370     """
# --> 371     return check_niimg(niimg, ensure_ndim=3, dtype=dtype)
#
# File ~/williamblair/miniconda/envs/tensorflow/lib/python3.8/site-packages/nilearn/_utils/niimg_conversions.py:303, in check_niimg(niimg, ensure_ndim, atleast_4d, dtype, return_iterator, wildcards)
#     301         raise ValueError(message)
#     302     else:
# --> 303         raise ValueError(f"File not found: '{niimg}'")
#     304 elif not os.path.exists(niimg):
#     305     raise ValueError(f"File not found: '{niimg}'")
#
# ValueError: File not found: '/Users/williamblair/project2/data/input/E03/output/T2w_1mm_noalign.nii.gz'
